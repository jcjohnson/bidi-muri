# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.misc import imread
from scipy.io import loadmat

# %matplotlib inline

# %%
data = loadmat('data/benchmark_images/benchmark.mat')
benchmark = data['BENCHMARK']

print benchmark.shape, type(benchmark)
print benchmark.dtype

num_images = benchmark.shape[1]


for t in xrange(500):
  image_id = benchmark[0, t][0]
  category_id = benchmark[0, t][1]
  unique_categories = benchmark[0, t][2]
  tot_labeled_objects = benchmark[0, t][3]
  filename = benchmark[0, t][4]
  height, width = benchmark[0, t][5], benchmark[0, t][6]
  name = benchmark[0, t][7]
  image_set = benchmark[0, t][9]
  print image_id.shape, category_id, unique_categories.shape, tot_labeled_objects.shape, name, image_set
# Out:
# (1, 2800) <type 'numpy.ndarray'>
# [('image_id', 'O'), ('category_id', 'O'), ('unique_categories', 'O'), ('tot_labeled_objects', 'O'), ('filename', 'O'), ('height', 'O'), ('width', 'O'), ('name', 'O'), ('supercategory', 'O'), ('image_set', 'O'), ('MIT', 'O')]
# (1, 1) [[1]] (2, 1) (3, 1) [u'person'] [u'train']
# (1, 1) [[1]] (2, 1) (2, 1) [u'person'] [u'train']
# (1, 1) [[1]] (3, 1) (13, 1) [u'person'] [u'train']
# (1, 1) [[1]] (2, 1) (3, 1) [u'person'] [u'train']
# (1, 1) [[1]] (3, 1) (5, 1) [u'person'] [u'train']
# (1, 1) [[1]] (6, 1) (39, 1) [u'person'] [u'train']
# (1, 1) [[1]] (3, 1) (13, 1) [u'person'] [u'train']
# (1, 1) [[1]] (2, 1) (4, 1) [u'person'] [u'train']
# (1, 1) [[1]] (5, 1) (8, 1) [u'person'] [u'train']
# (1, 1) [[1]] (3, 1) (3, 1) [u'person'] [u'train']
# (1, 1) [[1]] (3, 1) (11, 1) [u'person'] [u'train']
# (1, 1) [[1]] (2, 1) (3, 1) [u'person'] [u'train']
# (1, 1) [[1]] (5, 1) (12, 1) [u'person'] [u'train']
# (1, 1) [[1]] (4, 1) (14, 1) [u'person'] [u'train']
# ...
